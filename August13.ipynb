# %%
a=int(input("Enter a number: "))
if a<0:
    print("The number is negative")
elif a>0:
    print("The number is positive")

else:
    print("The number is zero")
# Out:
# Enter a number:  1
# The number is positive

# %%
b=int(input("Enter  number: "))
if b%2==0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# Enter  number:  2
# The number is even

# %%
num = int(input("Enter a number: "))
if num % 3 == 0 and num % 5 == 0:
    print("Fizzbuzz") 
elif num % 3 == 0:
    print("Fizz")
elif num % 5 == 0:
    print("Buzz")


else :
    print("not divisible by both")
# Out:
# Enter a number:  15
# Fizzbuzz

# %%
s="instagram"
len(s)
# Out:
# 9

# %%
s[3]
# Out:
# 't'

# %%
s[3],s[4],s[5]
# Out:
# ('t', 'a', 'g')

# %%
substring=(s[3]+s[4]+s[5])

# %%
print(substring)
# Out:
# tag

# %%
s[3]+s[4]+s[5]
# Out:
# 'tag'

# %%
s[-1]
# Out:
# 'm'

# %%
subs1=(s[-1])

# %%
subs1
# Out:
# 'm'

# %%
name = "Chaitanya Vijaykumar Shirkande"

print(name[0:9])      
print(name[10:21])     
print(name[-9:])     
print(name[15:21])   
print(len(name))
# Out:
# Chaitanya
# Vijaykumar
# Shirkande
# kumar
# 30

# %%
substring2=(name[3]+name[4]+name[5])

# %%
print (substring2)
# Out:
# ita
