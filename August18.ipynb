# %%
s="good morning"
# print(len(s))
count=0

for char in s: 
    if char=="g":
        count+=1
print("Frequency of 'g':",count)
# Out:
# Frequency of 'g': 2

# %%
s="Programming"
a=input("enter the character: ")
count=0
for char in s:
    if char==a:
        count+=1
print("Frequency of",a,"is:",count)
# Out:
# Frequency of h is: 0

# %%
s=input("Enter the string:")
a=input("enter the character: ")
count=0
for char in s:
    if char==a:
        count+=1
print("Frequency of",a,"is:",count)
# Out:
# Frequency of h is: 1

# %%
s="I love py thon prog ramming"
# a=input("enter the character: ")
count=0
for char in s:
    if char==" ":
        count+=1
print(s)
print("Frequency of spaces is:",count)
# Out:
# I love py thon prog ramming
# Frequency of spaces is: 5

# %%
s=input("enter the character: ")
a=s[::-1]
print(a)
if s.lower()==a.lower():
    print("this is palindrome")
else:
    print("this is not palindrome")
# Out:
# madaM
# this is palindrome
