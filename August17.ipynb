# %% [markdown]
# String Slicing with step value

# %%
s1="this is Homework"
s1
# Out:
# 'this is Homework'

# %%
#capitalize
s1.capitalize()
# Out:
# 'This is homework'

# %%
#casefold
s1.casefold()
# Out:
# 'this is homework'

# %%
#center
s1.center(20,"-")
# Out:
# '--this is Homework--'

# %%
#count
s1.count("o")
# Out:
# 2

# %%
#endswith
s1.endswith("rk")
# Out:
# True

# %%
#expandtabs()
s2="hello \tworld"
s2.expandtabs()
# Out:
# 'hello   world'

# %%
#find
s1.find("is")
# Out:
# 2

# %%
s1.format("hom")
# Out:
# 'this is Homework'

# %%
s1.index("i")
# Out:
# 2

# %%
s1.isalnum()
# Out:
# False

# %%
s1.isalpha()
# Out:
# False

# %%
s1.isdecimal()
# Out:
# False

# %%
s1.isdigit()
# Out:
# False

# %%
#lower
s1.islower()
# Out:
# False

# %%
s1.swapcase()
# Out:
# 'THIS IS hOMEWORK'

# %%
s1.zfill(30)
# Out:
# '00000000000000this is Homework'

# %%
s1.rjust(30,"-")
# Out:
# '--------------this is Homework'
