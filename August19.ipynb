# %%
batch_1314_db=["Sagar", "Rohit", "Anjali", 573893859,[1,23.4],"Om","Ram"]
filtered_list=[]
print(batch_1314_db)
l1=[]
for name in batch_1314_db:
    if isinstance(name,str):
        filtered_list.append(name)
        if len(name)>=5:
            l1.append(name)


print(filtered_list)
print(l1)
# Out:
# ['Sagar', 'Rohit', 'Anjali', 573893859, [1, 23.4], 'Om', 'Ram']
# ['Sagar', 'Rohit', 'Anjali', 'Om', 'Ram']
# ['Sagar', 'Rohit', 'Anjali']

# %%
for i in filtered_list:
    print(i[::-1])
# Out:
# ragaS
# tihoR
# ilajnA
# mO
# maR

# %%
for i in filtered_list:
    # print(filtered_list)
    if len(i)>2: 
        if "m" in i:
            print(i)
# Out:
# Ram

# %%
for i in filtered_list:
    if "m" in i:
                print(i)
# Out:
# Om
# Ram

# %%
filtered_list.sort()
filtered_list
# Out:
# ['Anjali', 'Om', 'Ram', 'Rohit', 'Sagar']
