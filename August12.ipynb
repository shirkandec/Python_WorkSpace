# %%
print("hello world")
# Out:
# hello world

# %%
year=int(input("Enter year: "))
if (year % 4) == 0:
    print("{0} is a leap year".format(year))
else:
    print("{0} is not a leap year".format(year))
# Out:
# 2444 is a leap year
