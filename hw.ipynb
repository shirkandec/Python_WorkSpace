# %%
s1="this is /tHomework"
s1
# Out:
# 'this is /tHomework'

# %%
#capitalize
s1.capitalize()
# Out:
# 'This is /thomework'

# %%
#casefold
s1.casefold()
# Out:
# 'this is /thomework'

# %%
#center
s1.center(20,"-")
# Out:
# '-this is /tHomework-'

# %%
#count
s1.count("o")
# Out:
# 2

# %%
#encode
s1.encode()
# Out:
# b'this is Homework'

# %%
#endswith
s1.endswith("rk")
# Out:
# True

# %%
#expandtabs()
s1.expandtabs()
# Out:
# 'this is /tHomework'
